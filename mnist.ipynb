# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Flatten())

# %%
model.add(tf.keras.layers.Dense(784, activation=tf.nn.relu))

# %%
model.add(tf.keras.layers.Dense(784, activation=tf.nn.relu))

# %%
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0830 - accuracy: 0.9804
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0789 - accuracy: 0.9818
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0749 - accuracy: 0.9830
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0761 - accuracy: 0.9830
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0686 - accuracy: 0.9838

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2006 - accuracy: 0.9642

# %%
model.save('epic_num_reader.model')
# Out:
# INFO:tensorflow:Assets written to: epic_num_reader.model/assets

# %%
new_model = tf.keras.models.load_model('epic_num_reader.model')

# %%
predictions = new_model.predict(x_test)

# %%
predictions
# Out:
# array([[8.5228489e-26, 4.7710901e-23, 5.5951080e-14, ..., 9.9535191e-01,
#         1.6828347e-23, 4.6480270e-03],
#        [9.4675230e-23, 2.8271482e-30, 1.0000000e+00, ..., 1.1751652e-20,
#         1.3632920e-22, 1.9863790e-38],
#        [1.8278108e-30, 1.0000000e+00, 1.7978597e-16, ..., 2.2432448e-13,
#         2.1045565e-18, 6.6128379e-12],
#        ...,
#        [1.4036142e-37, 0.0000000e+00, 3.8837141e-31, ..., 7.7145670e-29,
#         5.4331196e-28, 1.2998888e-24],
#        [2.5007676e-33, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         4.2601906e-23, 8.8048894e-32],
#        [4.2988972e-07, 1.4414897e-21, 4.9227421e-19, ..., 0.0000000e+00,
#         7.6897460e-19, 5.4298577e-23]], dtype=float32)

# %%
import numpy as np
for i in range(0,100):
    plt.imshow(x_test[i],cmap=plt.cm.binary)
    plt.title("predictions " + str(np.argmax(predictions[i])))
    plt.show()
